# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

df = pd.read_csv('survey_results_public.csv', low_memory=False)
df1 = pd.read_csv('survey_results_schema.csv')

df.columns = df.columns.str.strip()

total_respondents = len(df)
print(f"Загальна кількість респондентів: {total_respondents}")
# Out:
# Загальна кількість респондентів: 49191

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 2               3                     I am a developer by profession
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49188       49189                     I am a developer by profession
# 49189       49190                     I am a developer by profession
# 49190       49191  I am not primarily a developer, but I write co...
#
#                    Age                                            EdLevel  \
# ...

# %%
df1
# Out:
#         qid            qname  \
# 0     QID18    TechEndorse_1
# 1     QID18    TechEndorse_2
# 2     QID18    TechEndorse_3
# 3     QID18    TechEndorse_4
# 4     QID18    TechEndorse_5
# ..      ...              ...
# 134  QID103  AIAgentObsWrite
# 135   QID92  AIAgentExternal
# 136  QID104  AIAgentExtWrite
# 137  QID100          AIHuman
# 138   QID93           AIOpen
#
#                                               question type  \
# 0    What attracts you to a technology or causes yo...   RO
# 1    What attracts you to a technology or causes yo...   RO
# 2    What attracts you to a technology or causes yo...   RO
# 3    What attracts you to a technology or causes yo...   RO
# 4    What attracts you to a technology or causes yo...   RO
# ..                                                 ...  ...
# 134  Was the tool or tools for AI agent observabili...   TE
# 135  You indicated you use or develop AI agents as ...   MC
# 136  Was the out-of-the-box agents, copilots or ass...   TE
# ...

# %% [markdown]
# **Висновки:**
#
# **Успішне завантаження:** Робоче середовище Google Colab налаштовано, дані за 2025 рік успішно зчитані у змінні df та df1.
#
# **Обсяг та структура:** Датасет містить **49 191** рядків та **172** колонки. Велика кількість текстових даних object вказує на потребу в подальшій перевірці та очищенні для аналізу числових показників.
#
# **Технічна готовність:** Завдяки налаштуванню pd.set_option, текст курсивом текст курсивом забезпечено зручний доступ до всіх параметрів опитування. Етап підготовки завершено, дані готові до обробки.

# %%
total_respondents = df['ResponseId'].nunique()

print(f"Загальна кількість респондентів: {total_respondents}")
# Out:
# Загальна кількість респондентів: 49191

# %% [markdown]
# **Висновок:**
#
# **Загальна кількість:** Опитування охоплює **49 191** унікального респондента.
#
# **Метод підрахунку:** Використання .nunique() за колонкою ResponseId підтвердило відсутність дублікатів у даних.
#
# **Готовність:** Отримана вибірка є репрезентативною для подальшого аналізу трендів ІТ-індустрії.

# %%
questions = set(df1['qname'].unique()) & set(df.columns)

full_responses_count = df[list(questions)].dropna().shape[0]

print(f"Кількість респондентів, які відповіли на всі запитання: {full_responses_count}")
# Out:
# Кількість респондентів, які відповіли на всі запитання: 0

# %% [markdown]
# **Висновок:**
#
# **Результат аналізу:** Кількість респондентів, які надали відповіді на всі запитання без винятку, становить **0**.
#
# **Причина:** Опитування має складну структуру з багатьма специфічними та необов'язковими блоками. Наявність пропусків є природною, оскільки респонденти відповідають лише на ті питання, що стосуються їхнього досвіду.
#
# **Технічний підсумок:** Використання перетину множин гарантувало, що аналіз повноти відповідей проводився виключно за тими колонками, які офіційно зафіксовані у схемі опитування qname.

# %%
print(f'Міри центральної тенденції :')

print(f'Mean: {round(df.WorkExp.mean(), 1)}')

print(f'Median: {df.WorkExp.median()}')

print(f'Mode: {df.WorkExp.mode()[0]}')
# Out:
# Міри центральної тенденції :
# Mean: 13.4
# Median: 10.0
# Mode: 10.0

# %% [markdown]
# **Висновок:**
#
# **Центральна тенденція:** Обчислено основні статистичні показники для колонки WorkExp (досвід роботи респондентів).
#
# **Результати:** Середній стаж респондентів становить **13.4** року, тоді як медіанне значення **10.0** років. Найпопулярнішим показником досвіду (мода) є **10.0** років.
#
# **Аналіз:** Різниця між середнім - 13.4 та медіаною - 10.0 вказує на наявність у вибірці досвідчених спеціалістів, які зміщують середнє значення вгору. Проте типовий респондент має близько **10** років досвіду.

# %%
remote_count = df[df['RemoteWork'] == 'Remote'].shape[0]

print(f"Кількість респондентів, які працюють віддалено: {remote_count}")
# Out:
# Кількість респондентів, які працюють віддалено: 10931

# %% [markdown]
# **Висновок:**
#
# **Результат:** Кількість респондентів, які працюють віддалено — **10931**.
#
# **Технічний підсумок:** Розрахунок виконано шляхом фільтрації колонки RemoteWork за значенням "Remote" із застосуванням .shape[0].
#
# **Контекст:** Отримане число дозволяє оцінити частку дистанційної праці у загальній вибірці та порівняти її з іншими форматами зайнятості.

# %%
df['worked_with_python'] = df['LanguageHaveWorkedWith'].str.contains('python', case=False, na=False)

python_users_count = df['worked_with_python'].sum()

total_responses = df['LanguageHaveWorkedWith'].dropna().count()
python_percentage = (python_users_count / total_responses) * 100

print(f"Відсоток респондентів: {round(python_percentage, 1)}%")
# Out:
# Відсоток респондентів: 58.3%

# %% [markdown]
# **Висновок:**
#
# **Результат аналізу:** Частка респондентів, які використовують мову Python, становить **58.3%**.
#
# **Технічний підсумок:** Для аналізу було створено допоміжний булевий стовпець worked_with_python. Використання методу .str.contains() із параметром case=False забезпечило точне виявлення Python у рядках із множинними значеннями мов.
#
# **Аналіз:** Понад половина опитаних фахівців працюють з Python, що робить цю мову ключовим інструментом у вибірці. Це пояснює високий попит на Python-розробників та аналітиків даних.

# %%
df['learned_with_online_courses'] = df['LearnCode'].str.contains('Online Courses', case=False, na=False)

online_learners_count = df['learned_with_online_courses'].sum()

print(f"Кількість респондентів, які навчалися через онлайн-курси: {online_learners_count}")
# Out:
# Кількість респондентів, які навчалися через онлайн-курси: 10973

# %% [markdown]
# **Висновок:**
#
# **Результат аналізу:** Кількість респондентів, які зазначили онлайн-курси як один із методів навчання — **10973**.
#
# **Технічний підсумок:** Для ідентифікації відповідних записів створено булеву маску через метод .str.contains. Це дозволило коректно опрацювати множинні відповіді в колонці LearnCode, де онлайн-курси часто згадуються разом з іншими методами.
#
# **Аналіз:** Отримані дані підтверджують, що онлайн-освіта є одним із найпопулярніших способів здобуття знань в ІТ, що свідчить про гнучкість та доступність сучасних освітніх інструментів.

# %%
python_devs_with_salary = df[(df['worked_with_python'] == True) & (df['ConvertedCompYearly'].notna())]

py_progers_by_country = python_devs_with_salary.groupby('Country')['ConvertedCompYearly'].agg(['mean', 'median']).round(1)

py_progers_by_country.columns = ['Середня компенсація', 'Медіанна компенсація']

py_progers_by_country = py_progers_by_country.sort_values(by='Медіанна компенсація', ascending=False)

py_progers_by_country.head(20)
# Out:
#                                                     Середня компенсація  \
# Country
# Oman                                                           390135.0
# Andorra                                                        226103.5
# United States of America                                       173298.6
# Israel                                                         135828.4
# Switzerland                                                    156456.6
# Nomadic                                                        120131.6
# Ireland                                                        120523.9
# Luxembourg                                                     116014.7
# Kyrgyzstan                                                     106008.5
# Belize                                                         102121.0
# Belarus                                                         93666.7
# Iceland                                                         76083.0
# ...

# %% [markdown]
# **Висновок:**
#
# **Результат аналізу:** Сформовано рейтинг країн за рівнем річної компенсації Python-розробників. Лідерами за медіанним доходом у цій вибірці стали:
#
# **Оман ($390,135)**
#
# **Андорра ($226,103)**
#
# **США ($150,000)**
#
# **Ізраїль ($142,594)**
#
# **Технічний підсумок:** Для розрахунку використано комбінацію методів .groupby('Country') та .agg(['mean', 'median']). Попередня фільтрація забезпечила точність обчислень, а результати впорядковані за спаданням медіани для нівелювання впливу одиничних надвисоких зарплат.
#
# **Аналітичні спостереження:**
#
# 1. У багатьох країнах середня зарплата вища за медіану (як-от у США). Це підтверджує наявність "викидів" — поодиноких фахівців із надвисокими доходами, які штучно завищують середній показник.
# 2. Повна ідентичність середнього та медіани для Оману та Андорри вказує на малу кількість респондентів у цих локаціях. Показник США залишається найбільш репрезентативним еталоном через великий обсяг даних.
# 3. Високі позиції Швейцарії, Ізраїлю та категорії Nomadic підтверджують, що ринок Python-розробки є високооплачуваним у всьому світі, незалежно від географічної прив'язки.

# %%
top_5_edu = df[['ResponseId', 'EdLevel', 'ConvertedCompYearly']].sort_values(by='ConvertedCompYearly', ascending=False).reset_index(drop=True).head(5)

top_5_edu
# Out:
#    ResponseId                                          EdLevel  \
# 0       34268              Associate degree (A.A., A.S., etc.)
# 1       28701  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2       43144              Associate degree (A.A., A.S., etc.)
# 3       35354     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4       45972  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#    ConvertedCompYearly
# 0           50000000.0
# 1           33552715.0
# 2           18387548.0
# 3           15430267.0
# 4           13921760.0

# %% [markdown]
# **Висновок:**
#
# **Результат аналізу:** Сформовано перелік 5 респондентів з найвищою річною компенсацією. Результати демонструють аномально високі рівні доходу, які значно перевищують ринкові стандарти:
#
# **Associate degree: $50,000,000 (ResponseId: 34268)**
#
# **Master’s degree: $33,552,715 (ResponseId: 28701)**
#
# **Associate degree: $18,387,548 (ResponseId: 43144)**
#
# **Технічний підсумок:**
#
# 1. Виконано вибірку стовпців: ResponseId, EdLevel та ConvertedCompYearly.
# 2. Застосовано сортування за спаданням (ascending=False).
# 3. Використано .reset_index(drop=True) для чистої нумерації рейтингу (0–4) та .head(5) для обмеження вибірки.
#
# **Аналітичні спостереження:**
#
# 1. Виявлені суми (до $50 млн) є очевидними екстремальними викидами. Такі показники зазвичай свідчать про помилки респондентів при заповненні анкети — наприклад, введення місячного доходу замість річного (що при автоматичній конвертації дає мільйонні суми) або помилку у виборі валюти.
# 2. Дані показують, що в межах цього датасету найвищі, хоч і аномальні зарплати, не мають прямої залежності від наукового ступеня (наприклад, Associate degree випереджає Master’s). Це ще раз підкреслює, що в ІТ практичний досвід та конкретні навички часто важать більше, ніж формальна освіта.
# 3. Наявність таких записів підтверджує, що для аналізу реального ринку слід орієнтуватися виключно на медіану, оскільки середнє арифметичне через подібні випадки стає абсолютно нерепрезентативним.

# %%
age_python_stats = df.assign(is_python=df['LanguageHaveWorkedWith'].str.contains('Python', na=False)).groupby('Age')['is_python'].mean().mul(100).round(2).reset_index().rename(columns={'Age': 'Вікова категорія', 'is_python': 'Відсоток Python-розробників (%)'}).sort_values(by='Відсоток Python-розробників (%)', ascending=False)

age_python_stats
# Out:
#     Вікова категорія  Відсоток Python-розробників (%)
# 0    18-24 years old                            40.00
# 3    45-54 years old                            38.63
# 4    55-64 years old                            37.24
# 1    25-34 years old                            36.94
# 2    35-44 years old                            36.72
# 5  65 years or older                            31.63
# 6  Prefer not to say                            31.22

# %% [markdown]
# **Висновок:**
#
# **Результат аналізу:** Сформовано рейтинг популярності **Python** серед різних вікових груп. Лідером є категорія **18-24 years old (40.0%)**, а найменший відсоток спостерігається у групі **Prefer not to say (31.22%)**.
#
# **Технічний підсумок:**
#
# 1. Створено індикатор володіння мовою через пошук підрядка "Python" у колонці технологій.
# 2. Проведено групування за віком з розрахунком середнього значення (частки) позитивних відповідей.
# 3. Дані трансформовано у відсотки, заокруглено та відсортовано за спаданням для наочності рейтингу.
#
# **Аналітичні спостереження:**
#
# 1. Найвищий рівень використання **Python** серед молоді **(40.0%)** підтверджує статус мови як основної для навчання та старту кар'єри в IT.
# 2. Цікаво, що групи **від 25 до 54 років** демонструють дуже стабільний і близький показник **(в районі 36-38%)**, що свідчить про універсальність мови для досвідчених спеціалістів.
# 3. Навіть у найстаршій категорії **(65 years or older)** кожен третій розробник **(31.63%)** використовує Python, що підкреслює його актуальність незалежно від віку.

# %%
res = df[(df['ConvertedCompYearly'] > df['ConvertedCompYearly'].quantile(0.75)) & (df['RemoteWork'] == 'Remote')]['Industry'].value_counts().reset_index().rename(columns={'Industry': 'Індустрія', 'count': 'Кількість фахівців'})

industries_top_remote = pd.concat([res[res['Індустрія'] != 'Other:'], res[res['Індустрія'] == 'Other:']], ignore_index=True)

industries_top_remote
# Out:
#                                      Індустрія  Кількість фахівців
# 0                         Software Development                1186
# 1                                      Fintech                 190
# 2                                   Healthcare                 188
# 3   Internet, Telecomm or Information Services                 138
# 4                   Banking/Financial Services                  88
# 5                                   Government                  78
# 6                 Media & Advertising Services                  75
# 7                 Retail and Consumer Services                  65
# 8              Transportation, or Supply Chain                  63
# 9         Computer Systems Design and Services                  59
# 10                                   Insurance                  46
# 11                                      Energy                  45
# 12                               Manufacturing                  33
# ...

# %% [markdown]
# **Висновок:**
#
# **Результат аналізу:** Сформовано рейтинг індустрій для найбільш оплачуваних віддалених працівників (75-й перцентиль). Абсолютним лідером є **Software Development (1186)**, а друге та третє місця посідають **Fintech (190)** та **Healthcare (188)**. Категорію **Other (176)** переміщено в кінець списку для покращення візуального сприйняття основних галузей.
#
# **Технічний підсумок:**
#
# 1. Розраховано поріг 75-го перцентиля за допомогою .quantile(0.75) та відфільтровано респондентів за критеріями доходу та формату роботи "Remote".
# 2. Виконано підрахунок частоти індустрій через .value_counts().
# 3. Застосовано метод pd.concat для кастомного сортування, що дозволило відокремити специфічні індустрії від загальних відповідей та оновити індексацію через ignore_index=True.
#
# **Аналітичні спостереження:**
#
# 1. **Software Development** охоплює левову частку високооплачуваних віддалених позицій **(1186 фахівців)**, що підтверджує цифрову зрілість цієї галузі.
# 2. **Fintech** та **Healthcare** демонструють майже ідентичні показники (**190** та **188** відповідно), що вказує на однаково високу концентрацію капіталу та готовність цих індустрій платити за віддалену експертизу.
# 3. Галузь **Internet** та **Telecom** також входить у **топ-4** **(138 фахівців)**, замикаючи групу основних лідерів ринку.

# %% [markdown]
# **Загальні підсумки дослідження:**
#
# **Дані:** Опрацьовано повний датасет (49 191 запис). Очищення від NaN забезпечило точність розрахунків.
#
# **Зарплати:** Виявлено аномалії до $50 млн, тому для звіту використано медіану.
#
# **Python:** Найпопулярніший серед молоді 18–24 років (40.0%).
#
# **Індустрії:** Лідери віддаленої роботи — Software Development (1186), Fintech (190) та Healthcare (188).
#
# **Висновок:** Рівень доходу прямо залежить від стажу (медіана 10 років) та спеціалізації у високонавантажених секторах.
#
# **Ключовий інсайт:** Аналіз демонструє, що поєднання навичок Python-розробки з експертизою у фінансових чи медичних технологіях відкриває доступ до найбільш високооплачуваних сегментів ринку. Висока медіана досвіду (**10 років**) серед респондентів підтверджує, що стабільність доходу в індустрії безпосередньо корелює з практичним стажем.

# %% [markdown]
# ### **Візуалізація рівня доходів Python-розробників за країнами**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
top_salaries = py_progers_by_country.head(10)

sns.barplot(
    x=top_salaries['Медіанна компенсація'],
    y=top_salaries.index,
    hue=top_salaries.index,
    palette='viridis',
    legend=False
)

plt.title('Top 10 Countries by Median Python Developer Salary', fontsize=16)
plt.xlabel('Median Compensation (USD)', fontsize=12)
plt.ylabel('Country', fontsize=12)

plt.show()

# %% [markdown]
# **Дані демонструють, що США та Ізраїль залишаються лідерами за рівнем медіанної компенсації для Python-стеку.**

# %% [markdown]
# ### **Аналіз популярності Python серед різних вікових категорій**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plot_data = age_python_stats.reset_index()

plt.figure(figsize=(10, 6))

sns.lineplot(
    x=plot_data['Вікова категорія'],
    y=plot_data['Відсоток Python-розробників (%)'],
    marker='o', color='orange', linewidth=3
)

plt.title('Percentage of Python Developers across Different Age Groups', fontsize=14)
plt.ylabel('Percentage (%)', fontsize=12)
plt.xlabel('Age Category', fontsize=12)
plt.xticks(rotation=45)
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# **Спостерігається стабільно високий інтерес до Python серед молодих спеціалістів (18-24 роки), що вказує на перспективність мови.**

# %% [markdown]
# ## **Розподіл високооплачуваних remote-фахівців за галузями**

# %%
plt.figure(figsize=(10, 7))
top_industries = industries_top_remote.head(10)

sns.barplot(
    data=top_industries,
    x='Кількість фахівців',
    y='Індустрія',
    palette='magma',
    hue='Індустрія',
    legend=False
)

plt.title('Top Industries for High-Paying Remote Python Roles', fontsize=14, pad=20)
plt.xlabel('Number of Professionals', fontsize=12)
plt.ylabel('Industry', fontsize=12)
plt.show()

# %% [markdown]
# **Сектор Software Development та Fintech є найбільш привабливими для віддаленої роботи з високим рівнем оплати.**
